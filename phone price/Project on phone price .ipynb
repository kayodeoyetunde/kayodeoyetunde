# %% [markdown]
# # project price on mobile phone

# %% [markdown]
# **The goals**

# %% [markdown]
# *To knowe relation between features of a mobile phone(eg:- RAM,Internal Memory etc) and its selling price*
#
# *To know the price range*

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline
sns.set()

# %%
data = pd.read_csv('train.csv')
data.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %% [markdown]
# # prepare

# %%
data.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
data['price_range'].describe()
# Out:
# count    2000.000000
# mean        1.500000
# std         1.118314
# min         0.000000
# 25%         0.750000
# 50%         1.500000
# 75%         2.250000
# max         3.000000
# Name: price_range, dtype: float64

# %%
data.groupby('int_memory').mean()['price_range'].plot()
# Out:
# <AxesSubplot:xlabel='int_memory'>

# %% [markdown]
# # Analyze

# %% [markdown]
# **feature selection**

# %% [markdown]
# **quasi feature**

# %%
sel = VarianceThreshold(threshold=0.1)
sel.fit(data)
# Out:
# VarianceThreshold(threshold=0.1)

# %%
len(sel.get_feature_names_out())
# Out:
# 20

# %%
quasi_features = [col for col in data.columns if col not in sel.get_feature_names_out()]

# %%
quasi_features
# Out:
# ['m_dep']

# %% [markdown]
# **Correlated features**

# %%
corr_matrix = data.corr()

# %%
corr_features = [feature for feature in corr_matrix.columns if (corr_matrix[feature].iloc[corr_matrix.columns.get_loc(feature)] >0.8).any()]

# %%
corr_features
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
len(corr_features), len(quasi_features)
# Out:
# (21, 1)

# %% [markdown]
# # prepare training and test set

# %%
X = data.drop(['price_range'] + quasi_features, axis=1)
y = data['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
neigh = KNeighborsClassifier()
neigh.fit(X_train, y_train)
y_pred = neigh.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.9569044261964877

# %%
sns.histplot(y_train, bins=10)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='Count'>

# %% [markdown]
# #  Report

# %% [markdown]
# **present finding**

# %%
#The relation between features of a mobile phone with price_range
corr_features
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
#feature that is not releted with mobile phone price_range
quasi_features
# Out:
# ['m_dep']

# %% [markdown]
# # Visualization result

# %%
sns.histplot(y_train, bins=10)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='Count'>
